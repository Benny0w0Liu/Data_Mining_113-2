# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload

import KNN
import PLA
import SVM

reload(KNN)
reload(PLA)
reload(SVM)
# Out:
# Experiment A Accuracy(K=7): 73.13432835820896 %
# Experiment B Accuracy(K=7): 76.0 %
# <module 'SVM' from 'd:\\Github\\Data_Mining_113-2\\Data_Mining_Midterm\\SVM.py'>

# %% [markdown]
# # KNN

# %%
# Experiment A
ax = plt.gca()
ax.set_ylim([0, 100])
x = np.array(list(range(1,200,2)))
y=[]
for k in x:
    y.append(KNN.experiment("A",k))

print(f'Highest accuracy(marked point) : k = {x[np.argmax(y)]:.2f} -> Accuracy = {y[np.argmax(y)]:.2f}%')
plt.scatter(x[np.argmax(y)], y[np.argmax(y)], color='red', zorder=5)
plt.xlabel('value of k')
plt.ylabel('accuracy')
plt.title(f'KNN - Experiment A', fontsize=12)
plt.plot(x, y, 'b-')
# Out:
# Highest acurrency(marked point) : k = 17.00 -> Accuracy = 76.62%

# %%
# Experiment B
ax = plt.gca()
ax.set_ylim([0, 100])
x = np.array(list(range(1,200,2)))
y=[]
for k in x:
    y.append(KNN.experiment("B",k))

print(f'Highest accuracy(marked point) : k = {x[np.argmax(y)]:.2f} -> Accuracy = {y[np.argmax(y)]:.2f}%')
plt.scatter(x[np.argmax(y)], y[np.argmax(y)], color='red', zorder=5)
plt.xlabel('value of k')
plt.ylabel('accuracy')
plt.title(f'KNN - Experiment B', fontsize=12)
plt.plot(x, y, 'b-')
# Out:
# Highest acurrency(marked point) : k = 15.00 -> Accuracy = 78.00%

# %% [markdown]
# # PLA

# %%
# Experiment A
ax = plt.gca()
ax.set_ylim([0, 100])
x = np.array(list(range(10,1010,10)))
y=[]
for num in x:
    y.append(PLA.experiment("A",num))

print(f'Highest accuracy(marked point) : number of iter = {x[np.argmax(y)]:.2f} -> Accuracy = {y[np.argmax(y)]:.2f}%')
plt.scatter(x[np.argmax(y)], y[np.argmax(y)], color='red', zorder=5)
plt.xlabel('number of iter')
plt.ylabel('accuracy')
plt.title(f'PLA - Experiment A', fontsize=12)
plt.plot(x, y, 'b-')
# Out:
# Highest acurrency(marked point) : number of iter = 200.00 -> Accuracy = 67.66%

# %%
# Experiment B
ax = plt.gca()
ax.set_ylim([0, 100])
x = np.array(list(range(10,1010,10)))
y=[]
for num in x:
    y.append(PLA.experiment("B",num))

print(f'Highest accuracy(marked point) : number of iter = {x[np.argmax(y)]:.2f} -> Accuracy = {y[np.argmax(y)]:.2f}%')
plt.scatter(x[np.argmax(y)], y[np.argmax(y)], color='red', zorder=5)
plt.xlabel('number of iter')
plt.ylabel('accuracy')
plt.title(f'PLA - Experiment B', fontsize=12)
plt.plot(x, y, 'b-')
# Out:
# Highest acurrency(marked point) : number of iter = 360.00 -> Accuracy = 69.00%

# %% [markdown]
# # SVM

# %%
# Experiment A
ax = plt.gca()
ax.set_ylim([0, 100])
x = np.array(list(range(10,1010,10)))
y=[]
for num in x:
    y.append(SVM.experiment("A",num,1,0.005))
    
print(f'Highest accuracy(marked point) : number of iter = {x[np.argmax(y)]:.2f} -> Accuracy = {y[np.argmax(y)]:.2f}%')
plt.scatter(x[np.argmax(y)], y[np.argmax(y)], color='red', zorder=5)
plt.xlabel('number of iter')
plt.ylabel('accuracy')
plt.title(f'SVM - Experiment A', fontsize=12)
plt.plot(x, y, 'b-')

# %%
# Experiment B
ax = plt.gca()
ax.set_ylim([0, 100])
x = np.array(list(range(10,1010,10)))
y=[]
for num in x:
    y.append(SVM.experiment("B",num,1,0.005))
    
print(f'Highest accuracy(marked point) : number of iter = {x[np.argmax(y)]:.2f} -> Accuracy = {y[np.argmax(y)]:.2f}%')
plt.scatter(x[np.argmax(y)], y[np.argmax(y)], color='red', zorder=5)
plt.xlabel('number of iter')
plt.ylabel('accuracy')
plt.title(f'SVM - Experiment B', fontsize=12)
plt.plot(x, y, 'b-')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 7
#       5 y=[]
#       6 for num in x:
# ----> 7     y.append(SVM.experiment("B",num,1,0.005))
#       9 print(f'Highest acurrency(red point) : number of iter = {x[np.argmax(y)]:.2f} -> Accuracy = {y[np.argmax(y)]:.2f}%')
#      10 plt.scatter(x[np.argmax(y)], y[np.argmax(y)], color='red', zorder=5)
#
# File d:\Github\Data_Mining_113-2\Data_Mining_Midterm\SVM.py:75, in experiment(experiment, number_of_iter, C, tolerance)
#      73 test_tags = np.where(test_tags == 0, -1, 1)
#      74 #get Accuracy
# ---> 75 weight,bias=SVM(training_datas, training_tags, number_of_iter, C, tolerance)
#      76 test_pred = np.sign(np.dot(test_datas, weight) + bias)
#      77 accuracy = np.mean(test_tags == test_pred)
#
# ...
